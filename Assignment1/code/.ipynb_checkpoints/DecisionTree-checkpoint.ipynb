# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import sklearn
sklearn.__version__
# %matplotlib inline
from matplotlib import pyplot as plt
#from sklearn.tree

# %%
columns = ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'num']
df = pd.read_csv('../cleaned_processed.cleveland.data',header=None,names = columns)

# you could read .txt file using Pandas read_csv
df.head() # Display first five rows of the dataset 
df.columns
feature = columns[:13]
df.head()
# Out:
#     age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1  67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2  67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3  37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4  41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
#
#    slope   ca  thal  num
# 0    3.0  0.0   6.0    0
# 1    2.0  3.0   3.0    1
# 2    2.0  2.0   7.0    1
# 3    3.0  0.0   3.0    0
# 4    1.0  0.0   3.0    0

# %%
X = df[feature]
#,test_size = 0.2
y = df.num 
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=0)
clf = DecisionTreeClassifier(random_state=0)
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
X_train
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 159  46.0  1.0  2.0     101.0  197.0  1.0      0.0    156.0    0.0      0.0
# 90   62.0  0.0  4.0     160.0  164.0  0.0      2.0    145.0    0.0      6.2
# 269  71.0  0.0  4.0     112.0  149.0  0.0      0.0    125.0    0.0      1.6
# 157  60.0  1.0  4.0     140.0  293.0  0.0      2.0    170.0    0.0      1.2
# 198  64.0  0.0  4.0     180.0  325.0  0.0      0.0    154.0    1.0      0.0
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 251  43.0  1.0  4.0     115.0  303.0  0.0      0.0    181.0    0.0      1.2
# 192  67.0  1.0  4.0     100.0  299.0  0.0      2.0    125.0    1.0      0.9
# 117  63.0  1.0  4.0     130.0  330.0  1.0      2.0    132.0    1.0      1.8
# 47   50.0  1.0  4.0     150.0  243.0  0.0      2.0    128.0    0.0      2.6
# 172  64.0  1.0  4.0     145.0  212.0  0.0      2.0    132.0    0.0      2.0
#
#      slope   ca  thal
# 159    1.0  0.0   7.0
# 90     3.0  3.0   7.0
# 269    2.0  0.0   3.0
# 157    2.0  2.0   7.0
# 198    1.0  0.0   3.0
# ..     ...  ...   ...
# 251    2.0  0.0   3.0
# 192    2.0  2.0   3.0
# 117    1.0  3.0   7.0
# 47     2.0  0.0   7.0
# 172    2.0  2.0   6.0
#
# [222 rows x 13 columns]

# %%
pred = clf.predict(X_test)
accuracy_score(y_test,pred)
# Out:
# 0.76

# %%
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(clf,filled=True)
# Out:
# [Text(403.96875, 513.4, 'X[2] <= 3.5\ngini = 0.496\nsamples = 222\nvalue = [121, 101]'),
#  Text(180.1875, 453.0, 'X[0] <= 56.5\ngini = 0.291\nsamples = 113\nvalue = [93, 20]'),
#  Text(93.0, 392.6, 'X[3] <= 182.0\ngini = 0.131\nsamples = 71\nvalue = [66, 5]'),
#  Text(69.75, 332.2, 'X[9] <= 3.55\ngini = 0.108\nsamples = 70\nvalue = [66, 4]'),
#  Text(46.5, 271.8, 'X[12] <= 6.5\ngini = 0.083\nsamples = 69\nvalue = [66, 3]'),
#  Text(23.25, 211.39999999999998, 'gini = 0.0\nsamples = 54\nvalue = [54, 0]'),
#  Text(69.75, 211.39999999999998, 'X[10] <= 1.5\ngini = 0.32\nsamples = 15\nvalue = [12, 3]'),
#  Text(46.5, 151.0, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(93.0, 151.0, 'X[0] <= 51.0\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(69.75, 90.59999999999997, 'X[7] <= 181.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(46.5, 30.199999999999932, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(93.0, 30.199999999999932, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(116.25, 90.59999999999997, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(93.0, 271.8, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(116.25, 332.2, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(267.375, 392.6, 'X[1] <= 0.5\ngini = 0.459\nsamples = 42\nvalue = [27, 15]'),
#  Text(209.25, 332.2, 'X[0] <= 62.5\ngini = 0.188\nsamples = 19\nvalue = [17, 2]'),
#  Text(186.0, 271.8, 'X[7] <= 156.0\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(162.75, 211.39999999999998, 'X[11] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(139.5, 151.0, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(186.0, 151.0, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(209.25, 211.39999999999998, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(232.5, 271.8, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(325.5, 332.2, 'X[4] <= 244.5\ngini = 0.491\nsamples = 23\nvalue = [10, 13]'),
#  Text(279.0, 271.8, 'X[9] <= 2.45\ngini = 0.473\nsamples = 13\nvalue = [8, 5]'),
#  Text(255.75, 211.39999999999998, 'X[0] <= 57.5\ngini = 0.397\nsamples = 11\nvalue = [8, 3]'),
#  Text(232.5, 151.0, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(279.0, 151.0, 'X[4] <= 222.5\ngini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(255.75, 90.59999999999997, 'X[12] <= 4.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(232.5, 30.199999999999932, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(279.0, 30.199999999999932, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(302.25, 90.59999999999997, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(302.25, 211.39999999999998, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(372.0, 271.8, 'X[9] <= 3.55\ngini = 0.32\nsamples = 10\nvalue = [2, 8]'),
#  Text(348.75, 211.39999999999998, 'X[3] <= 121.5\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(325.5, 151.0, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(372.0, 151.0, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(395.25, 211.39999999999998, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(627.75, 453.0, 'X[12] <= 4.5\ngini = 0.382\nsamples = 109\nvalue = [28, 81]'),
#  Text(511.5, 392.6, 'X[11] <= 0.5\ngini = 0.499\nsamples = 38\nvalue = [20, 18]'),
#  Text(441.75, 332.2, 'X[0] <= 54.5\ngini = 0.403\nsamples = 25\nvalue = [18, 7]'),
#  Text(418.5, 271.8, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(465.0, 271.8, 'X[3] <= 116.0\ngini = 0.486\nsamples = 12\nvalue = [5, 7]'),
#  Text(441.75, 211.39999999999998, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(488.25, 211.39999999999998, 'X[4] <= 223.0\ngini = 0.42\nsamples = 10\nvalue = [3, 7]'),
#  Text(441.75, 151.0, 'X[8] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(418.5, 90.59999999999997, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(465.0, 90.59999999999997, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(534.75, 151.0, 'X[3] <= 177.0\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(511.5, 90.59999999999997, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(558.0, 90.59999999999997, 'X[10] <= 1.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(534.75, 30.199999999999932, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(581.25, 30.199999999999932, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(581.25, 332.2, 'X[6] <= 1.0\ngini = 0.26\nsamples = 13\nvalue = [2, 11]'),
#  Text(558.0, 271.8, 'X[0] <= 63.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(534.75, 211.39999999999998, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(581.25, 211.39999999999998, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(604.5, 271.8, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(744.0, 392.6, 'X[9] <= 0.65\ngini = 0.2\nsamples = 71\nvalue = [8, 63]'),
#  Text(720.75, 332.2, 'X[7] <= 149.0\ngini = 0.472\nsamples = 21\nvalue = [8, 13]'),
#  Text(651.0, 271.8, 'X[4] <= 237.0\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(627.75, 211.39999999999998, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(674.25, 211.39999999999998, 'X[7] <= 114.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(651.0, 151.0, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(697.5, 151.0, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(790.5, 271.8, 'X[11] <= 0.5\ngini = 0.337\nsamples = 14\nvalue = [3, 11]'),
#  Text(767.25, 211.39999999999998, 'X[0] <= 42.0\ngini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(744.0, 151.0, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(790.5, 151.0, 'X[6] <= 1.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(767.25, 90.59999999999997, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(813.75, 90.59999999999997, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(813.75, 211.39999999999998, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(767.25, 332.2, 'gini = 0.0\nsamples = 50\nvalue = [0, 50]')]

# %%
path = clf.cost_complexity_pruning_path(X_train, y_train)
ccp_alphas, impurities = path.ccp_alphas, path.impurities

# %%
ccp_alphas
# Out:
# array([0.        , 0.003861  , 0.00537379, 0.00559846, 0.00600601,
#        0.00646298, 0.00655201, 0.00675676, 0.00686401, 0.00720721,
#        0.00723938, 0.00735736, 0.00762301, 0.00801046, 0.00806401,
#        0.00878604, 0.01051051, 0.01912913, 0.01933523, 0.01968758,
#        0.02469709, 0.03815373, 0.1601985 ])

# %%
clfs = []
for ccp_alpha in ccp_alphas:
    clf = DecisionTreeClassifier(random_state=0, ccp_alpha=ccp_alpha)
    clf.fit(X_train, y_train)
    clfs.append(clf)
print("Number of nodes in the last tree is: {} with ccp_alpha: {}".format(
      clfs[-1].tree_.node_count, ccp_alphas[-1]))
# Out:
# Number of nodes in the last tree is: 1 with ccp_alpha: 0.1601984964761966

# %%
clfs = clfs[:-1]
ccp_alphas = ccp_alphas[:-1]

node_counts = [clf.tree_.node_count for clf in clfs]
depth = [clf.tree_.max_depth for clf in clfs]
fig, ax = plt.subplots(2, 1)
ax[0].plot(ccp_alphas, node_counts, marker='o', drawstyle="steps-post")
ax[0].set_xlabel("alpha")
ax[0].set_ylabel("number of nodes")
ax[0].set_title("Number of nodes vs alpha")
ax[1].plot(ccp_alphas, depth, marker='o', drawstyle="steps-post")
ax[1].set_xlabel("alpha")
ax[1].set_ylabel("depth of tree")
ax[1].set_title("Depth vs alpha")
fig.tight_layout()

# %%
train_scores = [clf.score(X_train, y_train) for clf in clfs]
test_scores = [clf.score(X_test, y_test) for clf in clfs]

fig, ax = plt.subplots()
ax.set_xlabel("alpha")
ax.set_ylabel("accuracy")
ax.set_title("Accuracy vs alpha for training and testing sets")
ax.plot(ccp_alphas, train_scores, marker='o', label="train",
        drawstyle="steps-post")
ax.plot(ccp_alphas, test_scores, marker='o', label="test",
        drawstyle="steps-post")
ax.legend()
plt.show()

# %%
clf = DecisionTreeClassifier(random_state=0, ccp_alpha=0.02)
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.02, random_state=0)

# %%
pred=clf.predict(X_test)
from sklearn.metrics import accuracy_score
accuracy_score(y_test, pred)
# Out:
# 0.7733333333333333

# %%
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(clf,filled=True)
# Out:
# [Text(334.8, 475.65000000000003, 'X[2] <= 3.5\ngini = 0.496\nsamples = 222\nvalue = [121, 101]'),
#  Text(167.4, 339.75, 'gini = 0.291\nsamples = 113\nvalue = [93, 20]'),
#  Text(502.20000000000005, 339.75, 'X[12] <= 4.5\ngini = 0.382\nsamples = 109\nvalue = [28, 81]'),
#  Text(334.8, 203.85000000000002, 'X[11] <= 0.5\ngini = 0.499\nsamples = 38\nvalue = [20, 18]'),
#  Text(167.4, 67.94999999999999, 'gini = 0.403\nsamples = 25\nvalue = [18, 7]'),
#  Text(502.20000000000005, 67.94999999999999, 'gini = 0.26\nsamples = 13\nvalue = [2, 11]'),
#  Text(669.6, 203.85000000000002, 'gini = 0.2\nsamples = 71\nvalue = [8, 63]')]

# %%
clf2 = DecisionTreeClassifier(random_state=0,criterion="entropy" ) 
clf2 = clf2.fit(X_train,y_train)

# %%
pred2 = clf2.predict(X_test)
accuracy_score(y_test,pred2)
# Out:
# 0.72

# %%
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(clf2,filled=True)
# Out:
# [Text(429.8108108108108, 522.6923076923077, 'X[2] <= 3.5\nentropy = 0.994\nsamples = 222\nvalue = [121, 101]'),
#  Text(203.59459459459458, 480.8769230769231, 'X[0] <= 56.5\nentropy = 0.673\nsamples = 113\nvalue = [93, 20]'),
#  Text(90.48648648648648, 439.0615384615385, 'X[12] <= 6.5\nentropy = 0.367\nsamples = 71\nvalue = [66, 5]'),
#  Text(45.24324324324324, 397.2461538461539, 'X[9] <= 3.55\nentropy = 0.131\nsamples = 55\nvalue = [54, 1]'),
#  Text(22.62162162162162, 355.4307692307692, 'entropy = 0.0\nsamples = 54\nvalue = [54, 0]'),
#  Text(67.86486486486487, 355.4307692307692, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(135.72972972972974, 397.2461538461539, 'X[4] <= 228.0\nentropy = 0.811\nsamples = 16\nvalue = [12, 4]'),
#  Text(113.1081081081081, 355.4307692307692, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(158.35135135135135, 355.4307692307692, 'X[11] <= 0.5\nentropy = 0.971\nsamples = 10\nvalue = [6, 4]'),
#  Text(135.72972972972974, 313.61538461538464, 'X[3] <= 115.0\nentropy = 0.811\nsamples = 8\nvalue = [6, 2]'),
#  Text(113.1081081081081, 271.8, 'X[3] <= 109.0\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(90.48648648648648, 229.98461538461538, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(135.72972972972974, 229.98461538461538, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(158.35135135135135, 271.8, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(180.97297297297297, 313.61538461538464, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(316.7027027027027, 439.0615384615385, 'X[1] <= 0.5\nentropy = 0.94\nsamples = 42\nvalue = [27, 15]'),
#  Text(271.4594594594595, 397.2461538461539, 'X[0] <= 62.5\nentropy = 0.485\nsamples = 19\nvalue = [17, 2]'),
#  Text(248.83783783783784, 355.4307692307692, 'X[7] <= 156.0\nentropy = 0.918\nsamples = 6\nvalue = [4, 2]'),
#  Text
 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(656.027027027027, 355.4307692307692, 'entropy = 0.0\nsamples = 16\nvalue = [0, 16]'),
#  Text(769.1351351351351, 439.0615384615385, 'X[6] <= 1.0\nentropy = 0.367\nsamples = 57\nvalue = [4, 53]'),
#  Text(746.5135135135135, 397.2461538461539, 'X[0] <= 63.5\nentropy = 0.65\nsamples = 24\nvalue = [4, 20]'),
#  Text(701.2702702702702, 355.4307692307692, 'X[5] <= 0.5\nentropy = 0.31\nsamples = 18\nvalue = [1, 17]'),
#  Text(678.6486486486486, 313.61538461538464, 'entropy = 0.0\nsamples = 16\nvalue = [0, 16]'),
#  Text(723.8918918918919, 313.61538461538464, 'X[11] <= 2.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(701.2702702702702, 271.8, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(746.5135135135135, 271.8, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(791.7567567567568, 355.4307692307692, 'X[5] <= 0.5\nentropy = 1.0\nsamples = 6\nvalue = [3, 3]'),
#  Text(769.1351351351351, 313.61538461538464, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(814.3783783783783, 313.61538461538464, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(791.7567567567568, 397.2461538461539, 'entropy = 0.0\nsamples = 33\nvalue = [0, 33]')]

# %%
path2 = clf2.cost_complexity_pruning_path(X_train, y_train)
ccp_alphas, impurities = path2.ccp_alphas, path2.impurities

# %%
clfs2 = []
for ccp_alpha in ccp_alphas:
    clf2 = DecisionTreeClassifier(random_state=0, ccp_alpha=ccp_alpha)
    clf2.fit(X_train, y_train)
    clfs2.append(clf2)
print("Number of nodes in the last tree is: {} with ccp_alpha: {}".format(
      clfs2[-1].tree_.node_count, ccp_alphas[-1]))
# Out:
# Number of nodes in the last tree is: 1 with ccp_alpha: 0.2477491715766973

# %%
clfs2 = clfs2[:-1]
ccp_alphas = ccp_alphas[:-1]

node_counts = [clf2.tree_.node_count for clf2 in clfs2]
depth = [clf2.tree_.max_depth for clf2 in clfs2]
fig, ax = plt.subplots(2, 1)
ax[0].plot(ccp_alphas, node_counts, marker='o', drawstyle="steps-post")
ax[0].set_xlabel("alpha")
ax[0].set_ylabel("number of nodes")
ax[0].set_title("Number of nodes vs alpha")
ax[1].plot(ccp_alphas, depth, marker='o', drawstyle="steps-post")
ax[1].set_xlabel("alpha")
ax[1].set_ylabel("depth of tree")
ax[1].set_title("Depth vs alpha")
fig.tight_layout()

# %%
train_scores = [clf2.score(X_train, y_train) for clf2 in clfs2]
test_scores = [clf2.score(X_test, y_test) for clf2 in clfs2]

fig, ax = plt.subplots()
ax.set_xlabel("alpha")
ax.set_ylabel("accuracy")
ax.set_title("Accuracy vs alpha for training and testing sets")
ax.plot(ccp_alphas, train_scores, marker='o', label="train",
        drawstyle="steps-post")
ax.plot(ccp_alphas, test_scores, marker='o', label="test",
        drawstyle="steps-post")
ax.legend()
plt.show()

# %%
clf2 = DecisionTreeClassifier(random_state=0, ccp_alpha=0.02)
clf2.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.02, random_state=0)

# %%
pred2=clf2.predict(X_test)
from sklearn.metrics import accuracy_score
accuracy_score(y_test, pred2)
# Out:
# 0.7733333333333333

# %%
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(clf2,filled=True)
# Out:
# [Text(334.8, 475.65000000000003, 'X[2] <= 3.5\ngini = 0.496\nsamples = 222\nvalue = [121, 101]'),
#  Text(167.4, 339.75, 'gini = 0.291\nsamples = 113\nvalue = [93, 20]'),
#  Text(502.20000000000005, 339.75, 'X[12] <= 4.5\ngini = 0.382\nsamples = 109\nvalue = [28, 81]'),
#  Text(334.8, 203.85000000000002, 'X[11] <= 0.5\ngini = 0.499\nsamples = 38\nvalue = [20, 18]'),
#  Text(167.4, 67.94999999999999, 'gini = 0.403\nsamples = 25\nvalue = [18, 7]'),
#  Text(502.20000000000005, 67.94999999999999, 'gini = 0.26\nsamples = 13\nvalue = [2, 11]'),
#  Text(669.6, 203.85000000000002, 'gini = 0.2\nsamples = 71\nvalue = [8, 63]')]

# %%
from sklearn.model_selection import GridSearchCV

def dtree_grid_search(data, target, nfolds):
    #create a dictionary of all values we want to test
    param_grid = { 'criterion':['gini','entropy'],'max_depth': np.arange(2, 10)}
    d_tree=DecisionTreeClassifier()
    
    gridsearch = GridSearchCV(d_tree, param_grid, cv=nfolds)
    gridsearch.fit(data, target)
    return gridsearch.best_params_
print("Best hyperparameter for this case:",dtree_grid_search(df, y, 3))
# Out:
# Best hyperparameter for this case: {'criterion': 'gini', 'max_depth': 2}

# %%
df3 = pd.read_csv('../housepricedata.csv')
df3
# Out:
#       LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 0        8450            7            5          856         2         1
# 1        9600            6            8         1262         2         0
# 2       11250            7            5          920         2         1
# 3        9550            7            5          756         1         0
# 4       14260            8            5         1145         2         1
# ...       ...          ...          ...          ...       ...       ...
# 1455     7917            6            5          953         2         1
# 1456    13175            6            6         1542         2         0
# 1457     9042            7            9         1152         2         0
# 1458     9717            5            6         1078         1         0
# 1459     9937            5            6         1256         1         1
#
#       BedroomAbvGr  TotRmsAbvGrd  Fireplaces  GarageArea  AboveMedianPrice
# 0                3             8           0         548                 1
# 1                3             6           1         460                 1
# 2                3             6           1         608                 1
# 3                3             7           1         642                 0
# 4                4             9           1         836                 1
# ...            ...           ...         ...         ...               ...
# 1455             3             7           1         460                 1
# 1456             3             7           2         500                 1
# 1457             4             9           2         252                 1
# 1458             2             5           0         240                 0
# 1459             3             6           0         276                 0
#
# [1460 rows x 11 columns]

# %%
dataset = df.values
dataset
# Out:
# array([[ 8450,     7,     5, ...,     0,   548,     1],
#        [ 9600,     6,     8, ...,     1,   460,     1],
#        [11250,     7,     5, ...,     1,   608,     1],
#        ...,
#        [ 9042,     7,     9, ...,     2,   252,     1],
#        [ 9717,     5,     6, ...,     0,   240,     0],
#        [ 9937,     5,     6, ...,     0,   276,     0]])

# %%
X = dataset[:,0:10]
y = dataset[:,10]

# %%
X_train3,X_test3,y_train3,y_test3 = train_test_split(X,y,random_state=0)
clf3 = DecisionTreeClassifier(random_state=0)
clf3.fit(X_train3,y_train3)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
pred3=clf3.predict(X_test3)
from sklearn.metrics import accuracy_score
accuracy_score(y_test3, pred3)
# Out:
# 0.8767123287671232

# %%
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(clf3,filled=True)
# Out:
# [Text(452.40252403846154, 522.6923076923077, 'X[1] <= 6.5\ngini = 0.5\nsamples = 1095\nvalue = [553, 542]'),
#  Text(275.2442307692308, 480.8769230769231, 'X[4] <= 1.5\ngini = 0.372\nsamples = 691\nvalue = [520, 171]'),
#  Text(138.02451923076924, 439.0615384615385, 'X[3] <= 1283.5\ngini = 0.187\nsamples = 451\nvalue = [404, 47]'),
#  Text(70.01826923076923, 397.2461538461539, 'X[8] <= 0.5\ngini = 0.128\nsamples = 421\nvalue = [392, 29]'),
#  Text(35.41153846153846, 355.4307692307692, 'X[9] <= 441.5\ngini = 0.04\nsamples = 294\nvalue = [288, 6]'),
#  Text(28.973076923076924, 313.61538461538464, 'gini = 0.0\nsamples = 212\nvalue = [212, 0]'),
#  Text(41.85, 313.61538461538464, 'X[6] <= 3.5\ngini = 0.136\nsamples = 82\nvalue = [76, 6]'),
#  Text(25.753846153846155, 271.8, 'X[3] <= 1120.5\ngini = 0.096\nsamples = 79\nvalue = [75, 4]'),
#  Text(12.876923076923077, 229.98461538461538, 'X[9] <= 886.0\ngini = 0.029\nsamples = 69\nvalue = [68, 1]'),
#  Text
#        0.00104371, 0.00114808, 0.00121766, 0.00124302, 0.00124319,
#        0.00128948, 0.00130001, 0.00136986, 0.00136986, 0.00146119,
#        0.00146119, 0.00149163, 0.00152985, 0.00153659, 0.00157426,
#        0.0015786 , 0.00159402, 0.00179553, 0.00203577, 0.00216964,
#        0.0022175 , 0.00248605, 0.00275603, 0.00278611, 0.00292237,
#        0.00300355, 0.00306309, 0.00366565, 0.00380518, 0.00389087,
#        0.00425009, 0.00456621, 0.00480514, 0.00649891, 0.00667266,
#        0.00718671, 0.00745205, 0.01307641, 0.01442853, 0.01520892,
#        0.01929788, 0.04867167, 0.20956137])

# %%
clfs3 = []
for ccp_alpha3 in ccp_alphas3:
    clf3 = DecisionTreeClassifier(random_state=0, ccp_alpha=ccp_alpha3)
    clf3.fit(X_train3, y_train3)
    clfs3.append(clf3)
print("Number of nodes in the last tree is: {} with ccp_alpha: {}".format(
      clfs3[-1].tree_.node_count, ccp_alphas3[-1]))
# Out:
# Number of nodes in the last tree is: 1 with ccp_alpha: 0.20956137162796912

# %%
train_scores3 = [clf3.score(X_train3, y_train3) for clf3 in clfs3]
test_scores3 = [clf3.score(X_test3, y_test3) for clf3 in clfs3]

fig, ax = plt.subplots()
ax.set_xlabel("alpha")
ax.set_ylabel("accuracy")
ax.set_title("Accuracy vs alpha for training and testing sets")
ax.plot(ccp_alphas3, train_scores3, marker='o', label="train",
        drawstyle="steps-post")
ax.plot(ccp_alphas3, test_scores3, marker='o', label="test",
        drawstyle="steps-post")
ax.legend()
plt.show()

# %%
clf3 = DecisionTreeClassifier(random_state=0, ccp_alpha=0.00)
clf3.fit(X_train3,y_train3)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
pred3=clf3.predict(X_test3)
from sklearn.metrics import accuracy_score
accuracy_score(y_test3, pred3)
# Out:
# 0.8767123287671232

# %%
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(clf3,filled=True)
# Out:
# [Text(452.40252403846154, 522.6923076923077, 'X[1] <= 6.5\ngini = 0.5\nsamples = 1095\nvalue = [553, 542]'),
#  Text(275.2442307692308, 480.8769230769231, 'X[4] <= 1.5\ngini = 0.372\nsamples = 691\nvalue = [520, 171]'),
#  Text(138.02451923076924, 439.0615384615385, 'X[3] <= 1283.5\ngini = 0.187\nsamples = 451\nvalue = [404, 47]'),
#  Text(70.01826923076923, 397.2461538461539, 'X[8] <= 0.5\ngini = 0.128\nsamples = 421\nvalue = [392, 29]'),
#  Text(35.41153846153846, 355.4307692307692, 'X[9] <= 441.5\ngini = 0.04\nsamples = 294\nvalue = [288, 6]'),
#  Text(28.973076923076924, 313.61538461538464, 'gini = 0.0\nsamples = 212\nvalue = [212, 0]'),
#  Text(41.85, 313.61538461538464, 'X[6] <= 3.5\ngini = 0.136\nsamples = 82\nvalue = [76, 6]'),
#  Text(25.753846153846155, 271.8, 'X[3] <= 1120.5\ngini = 0.096\nsamples = 79\nvalue = [75, 4]'),
#  Text(12.876923076923077, 229.98461538461538, 'X[9] <= 886.0\ngini = 0.029\nsamples = 69\nvalue = [68, 1]'),
#  Text(6.438461538461539, 188.1692307692308, 'gini = 0.0\nsamples = 65\nvalue = [65, 0]'),
#  Text(19.315384615384616, 188.1692307692308, 'X[9] <= 895.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(12.876923076923077, 146.35384615384618, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(25.753846153846155, 146.35384615384618, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(38.63076923076923, 229.98461538461538, 'X[3] <= 1136.5\ngini = 0.42\nsamples = 10\nvalue = [7, 3]'),
#  Text(32.19230769230769, 188.1692307692308, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(45.06923076923077, 188.1692307692308, 'X[3] <= 1241.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(38.63076923076923, 146.35384615384618, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(51.50769230769231, 146.35384615384618, 'X[5] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text
ngini = 0.34\nsamples = 23\nvalue = [5, 18]'),
#  Text(663.1615384615385, 313.61538461538464, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(676.0384615384615, 313.61538461538464, 'X[9] <= 633.5\ngini = 0.298\nsamples = 22\nvalue = [4, 18]'),
#  Text(663.1615384615385, 271.8, 'X[9] <= 479.0\ngini = 0.198\nsamples = 18\nvalue = [2, 16]'),
#  Text(656.723076923077, 229.98461538461538, 'X[7] <= 7.5\ngini = 0.346\nsamples = 9\nvalue = [2, 7]'),
#  Text(650.2846153846154, 188.1692307692308, 'X[0] <= 2538.0\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(643.8461538461538, 146.35384615384618, 'X[0] <= 2364.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(637.4076923076923, 104.53846153846155, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(650.2846153846154, 104.53846153846155, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(656.723076923077, 146.35384615384618, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(663.1615384615385, 188.1692307692308, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(669.6, 229.98461538461538, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(688.9153846153846, 271.8, 'X[6] <= 3.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(682.4769230769231, 229.98461538461538, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(695.3538461538462, 229.98461538461538, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(735.5942307692308, 355.4307692307692, 'X[9] <= 398.5\ngini = 0.034\nsamples = 344\nvalue = [6, 338]'),
#  Text(708.2307692307693, 313.61538461538464, 'X[0] <= 5528.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(701.7923076923078, 271.8, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(714.6692307692308, 271.8, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(762.9576923076924, 313.61538461538464, 'X[4] <= 1.5\ngini = 0.029\nsamples = 340\nvalue = [5, 335]'),
#  Text(727.5461538461539, 271.8, 'X[8] <= 0.5\ngini = 0.172\nsamples = 21\nvalue = [2, 19]'),
#  Text(721.1076923076923, 229.98461538461538, 'X[6] <= 1.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(714.6692307692308, 188.1692307692308, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(727.5461538461539, 188.1692307692308, 'X[9] <= 582.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(721.1076923076923, 146.35384615384618, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(733.9846153846154, 146.35384615384618, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(733.9846153846154, 229.98461538461538, 'gini = 0.0\nsamples = 17\nvalue = [0, 17]'),
#  Text(798.3692307692309, 271.8, 'X[9] <= 892.5\ngini = 0.019\nsamples = 319\nvalue = [3, 316]'),
#  Text(772.6153846153846, 229.98461538461538, 'X[3] <= 836.0\ngini = 0.013\nsamples = 299\nvalue = [2, 297]'),
#  Text(753.3000000000001, 188.1692307692308, 'X[3] <= 831.5\ngini = 0.095\nsamples = 20\nvalue = [1, 19]'),
#  Text(746.8615384615384, 146.35384615384618, 'gini = 0.0\nsamples = 17\nvalue = [0, 17]'),
#  Text(759.7384615384616, 146.35384615384618, 'X[6] <= 3.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(753.3000000000001, 104.53846153846155, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(766.1769230769231, 104.53846153846155, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(791.9307692307692, 188.1692307692308, 'X[9] <= 479.0\ngini = 0.007\nsamples = 279\nvalue = [1, 278]'),
#  Text(785.4923076923077, 146.35384615384618, 'X[9] <= 476.0\ngini = 0.048\nsamples = 41\nvalue = [1, 40]'),
#  Text(779.0538461538462, 104.53846153846155, 'gini = 0.0\nsamples = 38\nvalue = [0, 38]'),
#  Text(791.9307692307692, 104.53846153846155, 'X[7] <= 6.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(785.4923076923077, 62.72307692307692, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(798.3692307692309, 62.72307692307692, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(798.3692307692309, 146.35384615384618, 'gini = 0.0\nsamples = 238\nvalue = [0, 238]'),
#  Text(824.123076923077, 229.98461538461538, 'X[9] <= 896.5\ngini = 0.095\nsamples = 20\nvalue = [1, 19]'),
#  Text(817.6846153846154, 188.1692307692308, 'X[6] <= 2.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(811.2461538461539, 146.35384615384618, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(824.123076923077, 146.35384615384618, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(830.5615384615385, 188.1692307692308, 'gini = 0.0\nsamples = 18\nvalue = [0, 18]')]

# %%
X_train4,X_test4,y_train4,y_test4 = train_test_split(X,y,random_state=0)
clf4 = DecisionTreeClassifier(random_state=0,criterion="entropy")
clf4.fit(X_train4,y_train4)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
pred4=clf4.predict(X_test4)
from sklearn.metrics import accuracy_score
accuracy_score(y_test4, pred4)
# Out:
# 0.8602739726027397

# %%
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(clf4,filled=True)
# Out:
# [Text(510.7474888392857, 524.1857142857143, 'X[1] <= 6.5\nentropy = 1.0\nsamples = 1095\nvalue = [553, 542]'),
#  Text(291.9224330357143, 485.3571428571429, 'X[4] <= 1.5\nentropy = 0.807\nsamples = 691\nvalue = [520, 171]'),
#  Text(105.09207589285714, 446.52857142857147, 'X[8] <= 0.5\nentropy = 0.482\nsamples = 451\nvalue = [404, 47]'),
#  Text(37.36607142857143, 407.70000000000005, 'X[9] <= 441.5\nentropy = 0.178\nsamples = 299\nvalue = [291, 8]'),
#  Text(29.892857142857142, 368.8714285714286, 'entropy = 0.0\nsamples = 214\nvalue = [214, 0]'),
#  Text(44.839285714285715, 368.8714285714286, 'X[5] <= 0.5\nentropy = 0.45\nsamples = 85\nvalue = [77, 8]'),
#  Text(14.946428571428571, 330.0428571428572, 'X[0] <= 9850.5\nentropy = 0.196\nsamples = 66\nvalue = [64, 2]'),
#  Text(7.473214285714286, 291.2142857142857, 'entropy = 0.0\nsamples = 50\nvalue = [50, 0]'),
#  Text(22.419642857142858, 291.2142857142857, 'X[0] <= 10068.5\nentropy = 0.544\nsamples = 16\nvalue = [14, 2]'),
#  Text(14.946428571428571, 252.3857142857143, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(29.892857142857142, 252.3857142857143, 'X[9] <= 768.0\nentropy = 0.353\nsamples = 15\nvalue = [14, 1]'),
#  Text(22.419642857142858, 213.55714285714288, 'entropy = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(37.36607142857143, 213.55714285714288, 'X[3] <= 953.0\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(29.892857142857142, 174.72857142857146, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(44.839285714285715, 174.72857142857146, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(74.73214285714286, 330.0428571428572, 'X[0] <= 10072.0\nentropy = 0.9\nsamples = 19\nvalue = [13, 6]'),
#  Text(67.25892857142857, 291.2142857142857, 'X[3] <= 1108.5\nentropy = 1.0\nsamples = 12\nvalue = [6, 6]'),
#  Text(59.785714285714285, 252.3857142857143, 'X[3] <= 832.0\nentropy = 0.811\nsamples = 8\nvalue = [6, 2]'),
#  Text(52.3125, 213.55714285714288, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(67.25892857142857, 213.55714285714288, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(74.73214285714286, 252.3857142857143, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(82.20535714285714, 291.2142857142857, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(172.81808035714286, 407.70000000000005, 'X[0] <= 9050.5\nentropy = 0.822\nsamples = 152\nvalue = [113, 39]'),
#  Text(119.57142857142857, 368.8714285714286, 'X[3] <= 1280.0\nentropy = 0.28\nsamples = 62\nvalue = [59, 3]'),
#  Text(104.625, 330.0428571428572, 'X[7] <= 8.5\nentropy = 0.124\nsamples = 59\nvalue = [58, 1]'),
#  Text(97.15178571428571, 291.2142857142857, 'entropy = 0.0\nsamples = 58\nvalue = [58, 0]'),
#  Text(112.09821428571428, 291.2142857142857, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(134.51785714285714, 330.0428571428572, 'X[7] <= 5.5\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(127.04464285714286, 291.2142857142857, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(141.99107142857142, 291.2142857142857, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(226.06473214285714, 368.8714285714286, 'X[3] <= 1158.5\nentropy = 0.971\nsamples = 90\nvalue = [54, 36]'),
#  Text(190.56696428571428, 330.0428571428572, 'X[1] <= 5.5\nentropy = 0.85\nsamples = 58\nvalue = [42, 16]'),
#  Text(156.9375, 291.2142857142857, 'X[0] <= 9290.5\nentropy = 0.33\nsamples = 33\nvalue = [31, 2]'),
#  Text(149.46428571428572, 252.3857142857143, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(164.41071428571428, 252.3857142857143, 'X[0] <= 14233.0\nentropy = 0.201\nsamples = 32\nvalue = [31, 1]'),
#  Text(156.9375, 213.55714285714288, 'entropy = 0.0\nsamples = 27\nvalue = [27, 0]'),
#  Text(171.88392857142856, 213.55714285714288, 'X[9] <= 293.5\nentropy = 0.722\nsamples = 5\nvalue = [4, 1]'),
#  Text(164.41071428571428, 174.72857142857146, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(179.35714285714286, 174.72857142857146, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(224.19642857142856, 291.2142857142857, 'X[7] <= 7.5\nentropy = 0.99\nsamples = 25\nvalue = [11, 14]'),
#  Text(216.72321428571428, 252.3857142857143, 'X[3] <= 1113.0\nentropy = 0.993\nsamples = 20\nvalue = [11, 9]'),
#  Text(209.25, 213.55714285714288, 'X[3] <= 1034.5\nentropy = 0.998\nsamples = 17\nvalue = [8, 9]'),
#  Text(194.30357142857142, 174.72857142857146, 'X[9] <= 264.0\nentropy = 0.946\nsamples = 11\nvalue = [7, 4]'),
#  Text(186.83035714285714, 135.90000000000003, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(201.77678571428572, 135.90000000000003, 'X[7] <= 4.5\nentropy = 0.764\nsamples = 9\nvalue = [7, 2]'),
#  Text(194.30357142857142, 97.07142857142861, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(209.25, 97.07142857142861, 'X[7] <= 6.5\nentropy = 0.544\nsamples = 8\nvalue = [7, 1]'),
#  Text(201.77678571428572, 58.24285714285713, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(216.72321428571428, 58.24285714285713, 'X[9] <= 436.0\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(209.25, 19.41428571428571, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(224.19642857142856, 19.41428571428571, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(224.19642857142856, 174.72857142857146, 'X[8] <= 1.5\nentropy = 0.65\nsamples = 6\nvalue = [1, 5]'),
#  Text(216.72321428571428, 135.90000000000003, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(231.66964285714286, 135.90000000000003, 'X[9] <= 511.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(224.19642857142856, 97.07142857142861, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(239.14285714285714, 97.07142857142861, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(224.19642857142856, 213.55714285714288, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(231.66964285714286, 252.3857142857143, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(261.5625, 330.0428571428572, 'X[9] <= 528.5\nentropy = 0.954\nsamples = 32\nvalue = [12, 20]'),
#  Text(254.08928571428572, 291.2142857142857, 'X[3] <= 1264.5\nentropy = 1.0\nsamples = 24\nvalue = [12, 12]'),
#  Text(246.61607142857142, 252.3857142857143, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(261.5625, 252.3857142857143, 'X[9] <= 470.5\nentropy = 0.971\nsamples = 20\nvalue = [8, 12]'),
#  Text(246.61607142857142, 213.55714285714288, 'X[2] <= 7.0\nentropy = 0.439\nsamples = 11\nvalue = [1, 10]'),
#  Text(239.14285714285714, 174.72857142857146, 'entropy = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(254.08928571428572, 174.72857142857146, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(276.50892857142856, 213.55714285714288, 'X[0] <= 17813.0\nentropy = 0.764\nsamples = 9\nvalue = [7, 2]'),
#  Text(269.0357142857143, 174.72857142857146, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(283.98214285714283, 174.72857142857146, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(269.0357142857143, 291.2142857142857, 'entropy = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(478.75279017857144, 446.52857142857147, 'X[5] <= 0.5\nentropy = 0.999\nsamples = 240\nvalue = [116, 124]'),
#  Text(419.4341517857143, 407.70000000000005, 'X[3] <= 1153.5\nentropy = 0.944\nsamples = 155\nvalue = [99, 56]'),
#  Text(375.52901785714283, 368.8714285714286, 'X[0] <= 13625.0\nentropy = 0.662\nsamples = 93\nvalue = [77, 16]'),
#  Text(332.5580357142857, 330.0428571428572, 'X[7] <= 6.5\nentropy = 0.432\nsamples = 79\nvalue = [72, 7]'),
#  Text(325.08482142857144, 291.2142857142857, 'entropy = 0.0\nsamples = 29\nvalue = [29, 0]'),
#  Text(340.03125, 291.2142857142857, 'X[2] <= 6.5\nentropy = 0.584\nsamples = 50\nvalue = [43, 7]'),
#  Text(306.4017857142857, 252.3857142857143, 'X[3] <= 842.0\nentropy = 0.384\nsamples = 40\nvalue = [37, 3]'),
#  Text(298.92857142857144, 213.55714285714288, 'entropy = 0.0\nsamples = 18\nvalue = [18, 0]'),
#  Text(313.875, 213.55714285714288, 'X[3] <= 896.0\nentropy = 0.575\nsamples = 22\nvalue = [19, 3]'),
#  Text(298.92857142857144, 174.72857142857146, 'X[6] <= 3.0\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(291.4553571428571, 135.90000000000003, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(306.4017857142857, 135.90000000000003, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(328.82142857142856, 174.72857142857146, 'X[8] <= 0.5\nentropy = 0.297\nsamples = 19\nvalue = [18, 1]'),
#  Text(321.3482142857143, 135.90000000000003, 'entropy = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(336.29464285714283, 135.90000000000003, 'X[1] <= 5.5\nentropy = 0.722\nsamples = 5\nvalue = [4, 1]'),
#  Text(328.82142857142856, 97.07142857142861, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(343.7678571428571, 97.07142857142861, 'X[3] <= 1052.0\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(336.29464285714283, 58.24285714285713, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(351.24107142857144, 58.24285714285713, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(373.6607142857143, 252.3857142857143, 'X[7] <= 9.5\nentropy = 0.971\nsamples = 10\nvalue = [6, 4]'),
#  Text(366.1875, 213.55714285714288, 'X[1] <= 5.5\nentropy = 0.811\nsamples = 8\nvalue = [6, 2]'),
#  Text(358.7142857142857, 174.72857142857146, 'X[3] <= 723.0\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(351.24107142857144, 135.90000000000003, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(366.1875, 135.90000000000003, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(373.6607142857143, 174.72857142857146, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(381.13392857142856, 213.55714285714288, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(418.5, 330.0428571428572, 'X[1] <= 5.5\nentropy = 0.94\nsamples = 14\nvalue = [5, 9]'),
#  Text(411.0267857142857, 291.2142857142857, 'X[0] <= 16365.5\nentropy = 0.954\nsamples = 8\nvalue = [5, 3]'),
#  Text(403.55357142857144, 252.3857142857143, 'X[1] <= 4.0\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]'),
#  Text(396.0803571428571, 213.55714285714288, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(411.0267857142857, 213.55714285714288, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(418.5, 252.3857142857143, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(425.9732142857143, 291.2142857142857, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(463.3392857142857, 368.8714285714286, 'X[7] <= 7.5\nentropy = 0.938\nsamples = 62\nvalue = [22, 40]'),
#  Text(448.3928571428571, 330.0428571428572, 'X[3] <= 1381.0\nentropy = 0.722\nsamples = 45\nvalue = [9, 36]'),
#  Text(440.91964285714283, 291.2142857142857, 'X[7] <= 6.5\nentropy = 0.985\nsamples = 21\nvalue = [9, 12]'),
#  Text(433.44642857142856, 252.3857142857143, 'X[3] <= 1260.0\nentropy = 0.949\nsamples = 19\nvalue = [7, 12]'),
#  Text(425.9732142857143, 213.55714285714288, 'X[3] <= 1228.0\nentropy = 1.0\nsamples = 14\nvalue = [7, 7]'),
#  Text(418.5, 174.72857142857146, 'X[7] <= 5.5\nentropy = 0.881\nsamples = 10\nvalue = [3, 7]'),
#  Text(411.0267857142857, 135.90000000000003, 'X[3] <= 1216.0\nentropy = 1.0\nsamples = 6\nvalue = [3, 3]'),
#  Text(403.55357142857144, 97.07142857142861, 'X[4] <= 2.5\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]'),
#  Text(396.0803571428571, 58.24285714285713, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(411.0267857142857, 58.24285714285713, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(418.5, 97.07142857142861, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(425.9732142857143, 135.90000000000003, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(433.44642857142856, 174.72857142857146, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(440.91964285714283, 213.55714285714288, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(448.3928571428571, 252.3857142857143, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(455.86607142857144, 291.2142857142857, 'entropy = 0.0\nsamples = 24\nvalue = [0, 24]'),
#  Text(478.2857142857143, 330.0428571428572, 'X[2] <= 6.5\nentropy = 0.787\nsamples = 17\nvalue = [13, 4]'),
#  Text(470.8125, 291.2142857142857, 'X[9] <= 533.0\nentropy = 0.371\nsamples = 14\nvalue = [13, 1]'),
#  Text(463.3392857142857, 252.3857142857143, 'entropy = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(478.2857142857143, 252.3857142857143, 'X[9] <= 567.0\nentropy = 0.65\nsamples = 6\nvalue = [5, 1]'),
#  Text(470.8125, 213.55714285714288, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(485.75892857142856, 213.55714285714288, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(485.75892857142856, 291.2142857142857, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(538.0714285714286, 407.70000000000005, 'X[0] <= 6715.0\nentropy = 0.722\nsamples = 85\nvalue = [17, 68]'),
#  Text(500.7053571428571, 368.8714285714286, 'X[7] <= 5.5\nentropy = 0.918\nsamples = 15\nvalue = [10, 5]'),
#  Text(493.23214285714283, 330.0428571428572, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(508.17857142857144, 330.0428571428572, 'X[0] <= 2769.0\nentropy = 0.439\nsamples = 11\nvalue = [10, 1]'),
#  Text(500.7053571428571, 291.2142857142857, 'entropy = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(515.6517857142857, 291.2142857142857, 'X[3] <= 835.5\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(508.17857142857144, 252.3857142857143, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(523.125, 252.3857142857143, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(575.4375, 368.8714285714286, 'X[3] <= 726.5\nentropy = 0.469\nsamples = 70\nvalue = [7, 63]'),
#  Text(553.0178571428571, 330.0428571428572, 'X[6] <= 3.5\nentropy = 0.94\nsamples = 14\nvalue = [5, 9]'),
#  Text(545.5446428571429, 291.2142857142857, 'X[3] <= 572.0\nentropy = 0.994\nsamples = 11\nvalue = [5, 6]'),
#  Text(538.0714285714286, 252.3857142857143, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(553.0178571428571, 252.3857142857143, 'X[3] <= 676.0\nentropy = 0.991\nsamples = 9\nvalue = [5, 4]'),
#  Text(545.5446428571429, 213.55714285714288, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(560.4910714285714, 213.55714285714288, 'X[9] <= 454.5\nentropy = 0.918\nsamples = 6\nvalue = [2, 4]'),
#  Text(553.0178571428571, 174.72857142857146, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(567.9642857142857, 174.72857142857146, 'X[9] <= 679.5\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(560.4910714285714, 135.90000000000003, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(575.4375, 135.90000000000003, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(560.4910714285714, 291.2142857142857, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(597.8571428571429, 330.0428571428572, 'X[9] <= 90.0\nentropy = 0.222\nsamples = 56\nvalue = [2, 54]'),
#  Text(590.3839285714286, 291.2142857142857, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(605.3303571428571, 291.2142857142857, 'X[1] <= 5.5\nentropy = 0.131\nsamples = 55\nvalue = [1, 54]'),
#  Text(597.8571428571429, 252.3857142857143, 'X[8] <= 0.5\nentropy = 0.592\nsamples = 7\nvalue = [1, 6]'),
#  Text(590.3839285714286, 213.55714285714288, 'X[3] <= 896.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(582.9107142857142, 174.72857142857146, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(597.8571428571429, 174.72857142857146, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(605.3303571428571, 213.55714285714288, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(612.8035714285714, 252.3857142857143, 'entropy = 0.0\nsamples = 48\nvalue = [0, 48]'),
#  Text(729.5725446428571, 485.3571428571429, 'X[9] <= 480.5\nentropy = 0.408\nsamples = 404\nvalue = [33, 371]'),
#  Text(652.0379464285714, 446.52857142857147, 'X[3] <= 696.5\nentropy = 0.861\nsamples = 95\nvalue = [27, 68]'),
#  Text(612.8035714285714, 407.70000000000005, 'X[8] <= 0.5\nentropy = 0.787\nsamples = 17\nvalue = [13, 4]'),
#  Text(605.3303571428571, 368.8714285714286, 'entropy = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(620.2767857142857, 368.8714285714286, 'X[9] <= 380.0\nentropy = 1.0\nsamples = 8\nvalue = [4, 4]'),
#  Text(612.8035714285714, 330.0428571428572, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(627.75, 330.0428571428572, 'X[0] <= 10375.5\nentropy = 0.722\nsamples = 5\nvalue = [1, 4]'),
#  Text(620.2767857142857, 291.2142857142857, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(635.2232142857142, 291.2142857142857, 'X[9] <= 414.0\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(627.75, 252.3857142857143, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(642.6964285714286, 252.3857142857143, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(691.2723214285714, 407.70000000000005, 'X[9] <= 398.5\nentropy = 0.679\nsamples = 78\nvalue = [14, 64]'),
#  Text(665.1160714285714, 368.8714285714286, 'X[0] <= 6710.0\nentropy = 0.995\nsamples = 24\nvalue = [11, 13]'),
#  Text(657.6428571428571, 330.0428571428572, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(672.5892857142857, 330.0428571428572, 'X[4] <= 1.5\nentropy = 0.787\nsamples = 17\nvalue = [4, 13]'),
#  Text(665.1160714285714, 291.2142857142857, 'X[9] <= 255.0\nentropy = 1.0\nsamples = 8\nvalue = [4, 4]'),
#  Text(657.6428571428571, 252.3857142857143, 'X[5] <= 0.5\nentropy = 0.722\nsamples = 5\nvalue = [1, 4]'),
#  Text(650.1696428571429, 213.55714285714288, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(665.1160714285714, 213.55714285714288, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(672.5892857142857, 252.3857142857143, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(680.0625, 291.2142857142857, 'entropy = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(717.4285714285714, 368.8714285714286, 'X[3] <= 781.0\nentropy = 0.31\nsamples = 54\nvalue = [3, 51]'),
#  Text(702.4821428571429, 330.0428571428572, 'X[0] <= 10967.5\nentropy = 0.811\nsamples = 8\nvalue = [2, 6]'),
#  Text(695.0089285714286, 291.2142857142857, 'X[3] <= 754.0\nentropy = 0.592\nsamples = 7\nvalue = [1, 6]'),
#  Text(687.5357142857142, 252.3857142857143, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(702.4821428571429, 252.3857142857143, 'X[5] <= 0.5\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(695.0089285714286, 213.55714285714288, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(709.9553571428571, 213.55714285714288, 'X[0] <= 2538.0\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(702.4821428571429, 174.72857142857146, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(717.4285714285714, 174.72857142857146, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(709.9553571428571, 291.2142857142857, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(732.375, 330.0428571428572, 'X[9] <= 476.0\nentropy = 0.151\nsamples = 46\nvalue = [1, 45]'),
#  Text(724.9017857142857, 291.2142857142857, 'entropy = 0.0\nsamples = 42\nvalue = [0, 42]'),
#  Text(739.8482142857142, 291.2142857142857, 'X[7] <= 6.5\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]'),
#  Text(732.375, 252.3857142857143, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(747.3214285714286, 252.3857142857143, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(807.1071428571429, 446.52857142857147, 'X[4] <= 1.5\nentropy = 0.138\nsamples = 309\nvalue = [6, 303]'),
#  Text(792.1607142857142, 407.70000000000005, 'X[3] <= 1202.0\nentropy = 0.667\nsamples = 23\nvalue = [4, 19]'),
#  Text(784.6875, 368.8714285714286, 'X[0] <= 11107.0\nentropy = 0.991\nsamples = 9\nvalue = [4, 5]'),
#  Text(777.2142857142857, 330.0428571428572, 'X[3] <= 742.0\nentropy = 0.918\nsamples = 6\nvalue = [4, 2]'),
#  Text(769.7410714285714, 291.2142857142857, 'X[0] <= 10200.0\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(762.2678571428571, 252.3857142857143, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(777.2142857142857, 252.3857142857143, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(784.6875, 291.2142857142857, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(792.1607142857142, 330.0428571428572, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(799.6339285714286, 368.8714285714286, 'entropy = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(822.0535714285714, 407.70000000000005, 'X[0] <= 10149.5\nentropy = 0.06\nsamples = 286\nvalue = [2, 284]'),
#  Text(814.5803571428571, 368.8714285714286, 'X[0] <= 9975.5\nentropy = 0.131\nsamples = 110\nvalue = [2, 108]'),
#  Text(807.1071428571429, 330.0428571428572, 'entropy = 0.0\nsamples = 101\nvalue = [0, 101]'),
#  Text(822.0535714285714, 330.0428571428572, 'X[9] <= 869.5\nentropy = 0.764\nsamples = 9\nvalue = [2, 7]'),
#  Text(814.5803571428571, 291.2142857142857, 'X[0] <= 10130.0\nentropy = 0.544\nsamples = 8\nvalue = [1, 7]'),
#  Text(807.1071428571429, 252.3857142857143, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(822.0535714285714, 252.3857142857143, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(829.5267857142857, 291.2142857142857, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(829.5267857142857, 368.8714285714286, 'entropy = 0.0\nsamples = 176\nvalue = [0, 176]')]

# %%
path4 = clf4.cost_complexity_pruning_path(X_train4, y_train4)
ccp_alphas4, impurities4 = path4.ccp_alphas, path4.impurities

# %%
ccp_alphas3
# Out:
# array([0.        , 0.00056534, 0.00059776, 0.0006031 , 0.00068493,
#        0.00073059, 0.00076104, 0.00079909, 0.00079909, 0.00079909,
#        0.0008058 , 0.00081177, 0.00082445, 0.00084801, 0.00085236,
#        0.00086576, 0.0008828 , 0.00088997, 0.00089664, 0.00090001,
#        0.00104371, 0.00114808, 0.00121766, 0.00124302, 0.00124319,
#        0.00128948, 0.00130001, 0.00136986, 0.00136986, 0.00146119,
#        0.00146119, 0.00149163, 0.00152985, 0.00153659, 0.00157426,
#        0.0015786 , 0.00159402, 0.00179553, 0.00203577, 0.00216964,
#        0.0022175 , 0.00248605, 0.00275603, 0.00278611, 0.00292237,
#        0.00300355, 0.00306309, 0.00366565, 0.00380518, 0.00389087,
#        0.00425009, 0.00456621, 0.00480514, 0.00649891, 0.00667266,
#        0.00718671, 0.00745205, 0.01307641, 0.01442853, 0.01520892,
#        0.01929788, 0.04867167, 0.20956137])

# %%
clfs4 = []
for ccp_alpha4 in ccp_alphas4:
    clf4 = DecisionTreeClassifier(random_state=0,criterion="entropy", ccp_alpha=ccp_alpha4)
    clf4.fit(X_train4, y_train4)
    clfs4.append(clf4)
print("Number of nodes in the last tree is: {} with ccp_alpha: {}".format(
      clfs4[-1].tree_.node_count, ccp_alphas4[-1]))
# Out:
# Number of nodes in the last tree is: 1 with ccp_alpha: 0.33995672091029716

# %%
train_scores4 = [clf4.score(X_train4, y_train4) for clf4 in clfs4]
test_scores4 = [clf4.score(X_test4, y_test4) for clf4 in clfs4]

fig, ax = plt.subplots()
ax.set_xlabel("alpha")
ax.set_ylabel("accuracy")
ax.set_title("Accuracy vs alpha for training and testing sets")
ax.plot(ccp_alphas4, train_scores4, marker='o', label="train",
        drawstyle="steps-post")
ax.plot(ccp_alphas4, test_scores4, marker='o', label="test",
        drawstyle="steps-post")
ax.legend()
plt.show()

# %%
clf4 = DecisionTreeClassifier(random_state=0,criterion="entropy", ccp_alpha=0.00)
clf4.fit(X_train4,y_train4)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
pred4=clf4.predict(X_test4)
from sklearn.metrics import accuracy_score
accuracy_score(y_test4, pred4)
# Out:
# 0.8602739726027397
